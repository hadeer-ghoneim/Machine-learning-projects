# %% [markdown]
# ![alt text](SMT/01.png)

# %% [markdown]
# ![alt text](SMT/02.png)

# %% [markdown]
# ![alt text](SMT/03.png)

# %% [markdown]
# ![alt text](SMT/04.png)

# %% [markdown]
# ![alt text](SMT/05.png)

# %% [markdown]
# ![alt text](SMT/06.png)
